# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from scipy.spatial import Delaunay

# %%
points = pd.read_csv("/Users/Synne/Documents/Skole/H2024/master/code/Point_Processes/sampled_points.csv").values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(points[:,0], points[:,1], points[:,2], s=2)
plt.show()

# %%
points = np.loadtxt("sampled_points.txt")  # The LGCP-sampled locations
tri = Delaunay(points)

np.savetxt("mesh_nodes.txt", points)
np.savetxt("mesh_simplices.txt", tri.simplices, fmt="%d")
